# %%
import pandas as pd
from gen_data import get_avg

# %%
df_flags = pd.read_pickle("flags.pkl")
df_avg, names = get_avg(df_flags)
display(names)
display(df_avg)
json_avg = df_avg.to_json(orient="columns")
json_avg
# Out:
# Alpha-2 code
# AF                             Afghanistan
# AL                                 Albania
# DZ                                 Algeria
# AS                          American Samoa
# AD                                 Andorra
# AO                                  Angola
# AI                                Anguilla
# AQ                              Antarctica
# AG                     Antigua and Barbuda
# AR                               Argentina
# AM                                 Armenia
# AW                                   Aruba
# AU                               Australia
# AT                                 Austria
# AZ                              Azerbaijan
# BS                                 Bahamas
# BH                                 Bahrain
# BD                              Bangladesh
# BB                                Barbados
# BY                                 Belarus
# BE                                 Belgium
# ...
